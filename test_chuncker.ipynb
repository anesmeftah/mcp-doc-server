# %%
from modules import chuncker

# %%
text = """
Chapter 1
Intro content for chapter 1.

Section 1.1
Overview of the system.

Section 1.2
More details here.

Part IV
Legacy notes go here.

Introduction
-----------
This section uses a dashed underline header.

Data Overview
============
This section uses an equals underline header.

Conclusion
---------
Wrap-up content.
"""

# %%
clean_text = chuncker.clean_page(text)

# %%
clean_text = [clean_text]

# %%
clean_text
# Out:
# ['\nChapter 1\nIntro content for chapter 1.\n\nSection 1.1\nOverview of the system.\n\nSection 1.2\nMore details here.\n\nPart IV\nLegacy notes go here.\n\nIntroduction\n----------This section uses a dashed underline header.\n\nData Overview\n============\nThis section uses an equals underline header.\n\nConclusion\n--------Wrap-up content.\n']

# %%
sections = chuncker.structure_segmentation(clean_text)
# Out:
# 320
# [{'id': 0, 'header': 'Chapter 1', 'page': 0, 'start_pos': 1, 'end_pos': 10, 'text': '\n'}, {'id': 1, 'header': 'Section 1.1', 'page': 0, 'start_pos': 41, 'end_pos': 52, 'text': '\nIntro content for chapter 1.\n\nSection 1.'}, {'id': 2, 'header': 'Section 1.2', 'page': 0, 'start_pos': 78, 'end_pos': 89, 'text': '\nOverview of the system.\n\nSection 1.2\nMore details here.\n\nPart IV\nLegacy notes'}, {'id': 3, 'header': 'Part IV', 'page': 0, 'start_pos': 110, 'end_pos': 117, 'text': '\nMore details here.\n\nPart IV\nLegacy notes go here.\n\nIntroduction\n----------This section uses a dashed underlin'}, {'id': 4, 'header': 'Data Overview\n============', 'page': 0, 'start_pos': 210, 'end_pos': 236, 'text': '\nLegacy notes go here.\n\nIntroduction\n----------This section uses a dashed underline header.\n\nData Overview\n============\nThis section uses an equals underline header.\n\nConclusion\n--------Wrap-up content.\n'}]

# %%
sections
# Out:
# []
